#  -6.62816837e-02  3.98413688e-02 -1.16711572e-01  6.42993674e-02
#   4.02920023e-02 -6.54741451e-02  1.95052419e-02  8.09995607e-02
#   5.36463037e-02  7.67970011e-02 -1.34852352e-02 -1.76919066e-08
#  -4.43935432e-02  9.20642074e-03 -8.79590362e-02  4.26921509e-02
#   7.31365010e-02  1.68427452e-02 -4.03262563e-02  1.85131337e-02
#   8.44172686e-02 -3.74476984e-02  3.02996598e-02  2.90641878e-02
#   6.36878833e-02  2.89750453e-02 -1.47270178e-02  1.77542642e-02
#  -3.36895213e-02  1.73160974e-02  3.37875411e-02  1.76826090e-01
#  -1.75533406e-02 -6.03077933e-02 -1.43394647e-02 -2.38536540e-02
#  -4.45530526e-02 -2.89850459e-02 -8.96776393e-02 -1.75935205e-03
#  -2.61486229e-02  5.93996840e-03 -5.18355705e-02  8.57279673e-02
#  -8.18399116e-02  8.35442636e-03  4.00790200e-02  4.17764261e-02
#   1.04573578e-01 -2.86562392e-03  1.96690951e-02  5.81047870e-03
#   1.33253587e-02  4.51001078e-02 -2.17588134e-02 -1.39492927e-02
#  -6.86992407e-02 -2.94112880e-03 -3.10765263e-02 -1.05854392e-01
#   6.91623986e-02 -4.24114801e-02 -4.67682108e-02 -3.64751033e-02
#   4.50399928e-02  6.09816797e-02 -6.56561255e-02 -5.45642618e-03
#  -1.86227132e-02 -6.31484315e-02 -3.87437120e-02  3.46733853e-02
#   5.55458069e-02  5.21628261e-02  5.61065376e-02  1.02063894e-01]

# %%
from sentence_transformers import SentenceTransformer, util

# Two lists of sentences
sentences1 = ['The cat sits outside',
             'A man is playing guitar',
             'The new movie is awesome']

sentences2 = ['The dog plays in the garden',
              'A woman watches TV',
              'The new movie is so great']

#Compute embedding for both lists
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

#Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings1, embeddings2)

#Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i]))
# Out:
# The cat sits outside 		 The dog plays in the garden 		 Score: 0.2838
# A man is playing guitar 		 A woman watches TV 		 Score: -0.0327
# The new movie is awesome 		 The new movie is so great 		 Score: 0.8939

# %%
# Single list of sentences
sentences = ['The cat sits outside',
             'A man is playing guitar',
             'I love pasta',
             'The new movie is awesome',
             'The cat plays in the garden',
             'A woman watches TV',
             'The new movie is so great',
             'Do you like pizza?']

#Compute embeddings
embeddings = model.encode(sentences, convert_to_tensor=True)

#Compute cosine-similarities for each sentence with each other sentence
cosine_scores = util.cos_sim(embeddings, embeddings)

#Find the pairs with the highest cosine similarity scores
pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

#Sort scores in decreasing order
pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)

for pair in pairs[0:10]:
    i, j = pair['index']
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences[i], sentences[j], pair['score']))
# Out:
# The new movie is awesome 		 The new movie is so great 		 Score: 0.8939
# The cat sits outside 		 The cat plays in the garden 		 Score: 0.6788
# I love pasta 		 Do you like pizza? 		 Score: 0.5096
# I love pasta 		 The new movie is so great 		 Score: 0.2560
# I love pasta 		 The new movie is awesome 		 Score: 0.2440
# A man is playing guitar 		 The cat plays in the garden 		 Score: 0.2105
# The new movie is awesome 		 Do you like pizza? 		 Score: 0.1969
# The new movie is so great 		 Do you like pizza? 		 Score: 0.1692
# The cat sits outside 		 A woman watches TV 		 Score: 0.1310
# The cat plays in the garden 		 Do you like pizza? 		 Score: 0.0900

# %%
import torch

embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Corpus with example sentences
corpus = ['A man is eating food.',
          'A man is eating a piece of bread.',
          'The girl is carrying a baby.',
          'A man is riding a horse.',
          'A woman is playing violin.',
          'Two men pushed carts through the woods.',
          'A man is riding a white horse on an enclosed ground.',
          'A monkey is playing drums.',
          'A cheetah is running behind its prey.'
          ]
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# Query sentences:
queries = ['A man is eating pasta.', 'Someone in a gorilla costume is playing a set of drums.', 'A cheetah chases prey on across a field.']


# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(5, len(corpus))
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(corpus[idx], "(Score: {:.4f})".format(score))
# Out:
# ======================
#
#
# Query: A man is eating pasta.
#
# Top 5 most similar sentences in corpus:
# A man is eating food. (Score: 0.7035)
# A man is eating a piece of bread. (Score: 0.5272)
# A man is riding a horse. (Score: 0.1889)
# A man is riding a white horse on an enclosed ground. (Score: 0.1047)
# A cheetah is running behind its prey. (Score: 0.0980)
#
#
# ======================
#
#
# Query: Someone in a gorilla costume is playing a set of drums.
#
# Top 5 most similar sentences in corpus:
# A monkey is playing drums. (Score: 0.6433)
# A woman is playing violin. (Score: 0.2564)
# A man is riding a horse. (Score: 0.1389)
# A man is riding a white horse on an enclosed ground. (Score: 0.1191)
# A cheetah is running behind its prey. (Score: 0.1080)
#
#
# ======================
#
#
# Query: A cheetah chases prey on across a field.
#
# Top 5 most similar sentences in corpus:
# A cheetah is running behind its prey. (Score: 0.8253)
# A man is eating food. (Score: 0.1399)
# A monkey is playing drums. (Score: 0.1292)
# A man is riding a white horse on an enclosed ground. (Score: 0.1097)
# A man is riding a horse. (Score: 0.0650)

# %%
df = pd.read_csv('annotations_20220816.tsv',delimiter = '\t', on_bad_lines='skip')

df.head()
# Out:
# /scratch/ials-gpu013/4253389/ipykernel_583942/4268294677.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('annotations_20220816.tsv',delimiter = '\t', on_bad_lines='skip')
#          id                                   text_to_annotate  start   end  \
# 0  98791999  Virt - Vite 2.5 - 25 - 1 MG Oral Tablet Vitami...    0.0   3.0
# 1  98791999  Virt - Vite 2.5 - 25 - 1 MG Oral Tablet Vitami...    7.0   8.0
# 2  98791999  Virt - Vite 2.5 - 25 - 1 MG Oral Tablet Vitami...    8.0   9.0
# 3  98791999  Virt - Vite 2.5 - 25 - 1 MG Oral Tablet Vitami...    9.0  10.0
# 4  98791999  Virt - Vite 2.5 - 25 - 1 MG Oral Tablet Vitami...   10.0  11.0
#
#       ann_text                                         definition
# 0  Virt - Vite  A mix of vitamins. It provides vitamin B-6, vi...
# 1            1                                    {DO NOT DEFINE}
# 2          MG         A tiny amount of something, usually a drug.
# 3         Oral                                    Taken by mouth.
# 4       Tablet                                            A pill.

# %%
df_term = df[['ann_text','definition']]

df_term['ann_text'] = df_term['ann_text'].astype(str)
df_term['definition'] = df_term['definition'].astype(str)
df_term.head()
# Out:
# /scratch/ials-gpu013/4253389/ipykernel_583942/3410138809.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_term['ann_text'] = df_term['ann_text'].astype(str)
# /scratch/ials-gpu013/4253389/ipykernel_583942/3410138809.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_term['definition'] = df_term['definition'].astype(str)
#       ann_text                                         definition
# 0  Virt - Vite  A mix of vitamins. It provides vitamin B-6, vi...
# 1            1                                    {DO NOT DEFINE}
# 2          MG         A tiny amount of something, usually a drug.
# 3         Oral                                    Taken by mouth.
# 4       Tablet                                            A pill.

# %%
df_term['ann_text'] = df_term['ann_text'].str.lower()
# Out:
# /scratch/ials-gpu013/4253389/ipykernel_583942/1337866649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_term['ann_text'] = df_term['ann_text'].str.lower()

# %%
df_term.head()
# Out:
#       ann_text                                         definition
# 0  virt - vite  A mix of vitamins. It provides vitamin B-6, vi...
# 1            1                                    {DO NOT DEFINE}
# 2          mg         A tiny amount of something, usually a drug.
# 3         oral                                    Taken by mouth.
# 4       tablet                                            A pill.

# %%
df_term_unique = df_term.drop_duplicates()

df_term_unique = df_term_unique[df_term_unique.definition != '{DO NOT DEFINE}']

print(len(df_term_unique))
# Out:
# 42137

# %%
df_term_unique.head(30)
# Out:
#                    ann_text                                         definition
# 0               virt - vite  A mix of vitamins. It provides vitamin B-6, vi...
# 2                       mg         A tiny amount of something, usually a drug.
# 3                      oral                                    Taken by mouth.
# 4                    tablet                                            A pill.
# 5         vitamin b complex  A group of vitamins and nutrients.  The body n...
# 6                folic acid                                       A B vitamin.
# 7                 vitamin c  A nutrient needed by the body to form and main...
# 9                      tab                                             A pill.
# 10                       po                                          By mouth.
# 11                       qd                                         Every day.
# 12                allergies  Having a reaction to a drug or foreign substan...
# 13  no known drug allergies  The patient has not been shown to be allergic ...
# 14                      pm                        In the afternoon or evening.
# 15                   vitals  Measures that show how well the body is workin...
# 16              vital signs  Measures that show how well the body is workin...
# 17                    data                                        Information.
# 19                 appendix  A small, finger-like pouch at the beginning of...
# 21                treatment       Doing something to help a person get better.
# 23              ondansetron        A drug used to prevent nausea and vomiting.
# 27                      d5                       A mixture of sugar and water.
# 28          sodium chloride  An element in the fluid (salt) surrounding cel...
# 29                      ml   A measurement of volume (5 milliliters is abou...
# 30                      hr   A measure of how fast or slow the heart is bea...
# 31                 iv fluid  A mineral and salt water solution given throug...
# 32                     drip  A slow infusion of a medication via a tube int...
# 33                 protonix  A drug used to treat heartburn and ulcers. It ...
# 34              intravenous  When fluids and medicine are put directly into...
# 36                      iv   When fluids and medicine are put directly into...
# 37              medication     A drug used to treat symptoms and cure illness.
# 42                  iv push          Quickly injecting a medicine into a vein.

# %%
corpus = pd.read_csv('df_annotations_all_definitions_unique.csv')

# %%
print(len(corpus))
print(len(pd.DataFrame(corpus.loc[corpus['definition'] != "not found in UMLS"])))

testing = pd.DataFrame(corpus.loc[corpus['definition'] != "not found in UMLS"])
testing.head(50)
# Out:
# 87023
# 82471
#     Unnamed: 0                     name concept_id  \
# 2            0                     oral   C0226896
# 3            1                     oral   C0442027
# 4            2                     oral   C1272919
# 5            3                     oral   C1527415
# 6            4                     oral   C4521986
# 7            0                   tablet   C0039225
# 8            1                   tablet   C1705223
# 9            2                   tablet   C4319774
# 10           3                   tablet   C4722631
# 11           4                   tablet   C0993159
# 12           0        vitamin b complex   C0016410
# 13           1        vitamin b complex   C0042849
# 14           2        vitamin b complex   C0005492
# 15           3        vitamin b complex   C0042845
# 16           4        vitamin b complex   C0042850
# 17           0               folic acid   C0016410
# 18           1               folic acid   C0523631
# 19           2               folic acid   C0023413
# 20           3               folic acid   C1157038
# 21           4               folic acid   C1149539
# 22           0                vitamin c   C0003968
# 23           1                vitamin c   C0201898
# 24           2                vitamin c   C2349136
# 25           3                vitamin c   C3714687
# 26           4                vitamin c   C4522080
# 27           0                     tab    C0039225
# 28           1                     tab    C1705223
# 29           2                     tab    C0991507
# 30           3                     tab    C0993159
# 31           4                     tab    C1273629
# 33           0                       qd   C0332173
# 34           0                allergies   C0020517
# 35           1                allergies   C0199747
# 36           2                allergies   C0549104
# 37           3                allergies   C0859949
# 38           4                allergies   C0585186
# 39           0  no known drug allergies   C0013182
# 40           1  no known drug allergies   C0020517
# 42           0              vital signs   C0150404
# 43           1              vital signs   C0518766
# 44           2              vital signs   C1704629
# 45           3              vital signs   C2963216
# 46           4              vital signs   C2826644
# 47           0                    data    C1511726
# 48           1                    data    C3245479
# 49           2                    data    C3714741
# 50           3                    data    C1546437
# 51           4                    data    C1547350
# 52           0                 appendix   C0003617
# 53           1                 appendix   C1552860
#
#                        canonical_name  \
# 2                         Oral cavity
# 3                                Oral
# 4                    Oral Dosage Form
# 5   Oral Route of Drug administration
# 6                Oral (intended site)
# 7                  Tablet Dosage Form
# 8                  Tablet Dosing Unit
# 9       Tablet (unit of presentation)
# 10        Tablet Dosage Form Category
# 11                        Oral Tablet
# 12                         folic acid
# 13                  vitamin B complex
# 14                      Bioflavonoids
# 15                        vitamin B12
# 16               Vitamin B Deficiency
# 17                         folic acid
# 18             Folic acid measurement
# 19                         leucovorin
# 20        Folate Biosynthesis Pathway
# 21                 folic acid binding
# 22                      ascorbic acid
# 23          Ascorbic acid measurement
# 24                 Vitamin C Vitamins
# 25               Vitamin C Drug Class
# 26                    Vitamin C [EPC]
# 27                 Tablet Dosage Form
# 28                 Tablet Dosing Unit
# 29       Extended Release Oral Tablet
# 30                        Oral Tablet
# 31         Soluble Tablet Dosage Form
# 33                              Daily
# 34                   Hypersensitivity
# 35                    Allergy testing
# 36   In vivo test of hypersensitivity
# 37                    Allergy to meat
# 38         Cutaneous hypersensitivity
# 39                       Drug Allergy
# 40                   Hypersensitivity
# 42                 Taking vital signs
# 43                        Vital signs
# 44                 Vital Signs Domain
# 45           Vital signs measurements
# 46                   Vital Signs Date
# 47                               Data
# 48         Data call receiving device
# 49                   Data (eukaryote)
# 50           No Information Available
# 51                  Data types - Date
# 52                           Appendix
# 53               appendix - HTML link
#
#                                               aliases  \
# 2   ['Oral', 'Buccal Cavity', 'Buccal cavity', 'Or...
# 3   ['Oral', 'Orally', 'PO - Oral', 'oral', 'Oral ...
# 4   ['Oral', 'Oral Dosage Form', 'oral dosage form...
# 5   ['by mouth', 'PO - Per os', 'Oral Route of Adm...
# 6                    ['Oral', 'Oral (intended site)']
# 7   ['TAB', 'tab', 'TabletDrugForm', 'medicines ta...
# 8   ['Tablet Dosing Unit', '{Tablet}', 'Tablet', '...
# 9         ['Tablet', 'Tablet (unit of presentation)']
# 10          ['Tablet', 'Tablet Dosage Form Category']
# 11  ['oral tablets', 'Oral tablet', 'Conventional ...
# 12  ['Vitamin B c', 'Pteroyl-L-glutamic acid', 'Fo...
# 13  ['B Vitamins', 'Vitamin B and vitamin B deriva...
# 14  ['Product containing bioflavonoid', 'Bioflavon...
# 15  ['COBALAMIN', 'Cobalamin', 'vitamin-B12', 'CYA...
# 16  ['Deficiency of B-complex components', 'vitami...
# 17  ['Vitamin B c', 'Pteroyl-L-glutamic acid', 'Fo...
# 18  ['Folic acid measurement (procedure)', 'Folate...
# 19  ['L(-)-5-Formyl-5,6,7,8-tetrahydrofolic acid',...
# 20  ['folic acid synthesis', 'folate biosynthetic ...
# 21  ['folate binding', 'vitamin B9 binding', 'vita...
# 22  ['Vitamin-C', 'L-ascorbic acid', 'ácido ascórb...
# 23  ['Ascorbic Acid', 'Ascorbic acid measurement (...
# 24                                      ['Vitamin C']
# 25                                      ['VITAMIN C']
# 26  ['Vitamin C', 'Vitamin C-class Agent', 'Vitami...
# 27  ['TAB', 'tab', 'TabletDrugForm', 'medicines ta...
# 28  ['Tablet Dosing Unit', '{Tablet}', 'Tablet', '...
# 29  ['Extended-release oral tablet', 'Prolonged-re...
# 30  ['oral tablets', 'Oral tablet', 'Conventional ...
# 31  ['TAB SOLUBLE', 'Soluble Tablet', 'Tablet, Sol...
# 33  ['Each day', '/d', 'Every Day', 'everyday', 'Q...
# 34  ['Allergies', 'Hypersensitivity reaction (diso...
# 35  ['allergies tests', 'Allergy testing', 'Allerg...
# 36  ['allergies tests', 'Allergy testing', 'Allerg...
# 37  ['Allergy to meat allergens', 'Meat allergen a...
# 38  ['Cutaneous hypersensitivity', 'allergies skin...
# 39  ['allergy drugs', 'drugs hypersensitivity', 'D...
# 40  ['Allergies', 'Hypersensitivity reaction (diso...
# 42  ['monitoring vital signs', 'Vital signs', 'vit...
# 43  ['Vital signs', 'Vital Signs', 'vital signs', ...
# 44        ['Vital Signs Domain', 'Vital Signs', 'VS']
# 45  ['VS', 'Vital Signs Measurement', 'Vital Sign ...
# 46                                          ['VSDAT']
# 47            ['Datum', 'Data', 'data', 'Data Point']
# 48                                           ['data']
# 49                                           ['Data']
# 50  ['No Answer Provided', 'NO INFORMATION', 'Data...
# 51  ['date', 'Date Data Type', 'Date Value', 'Date...
# 52  ['Vermiform appendix', 'Appendix structure', '...
# 53                                       ['appendix']
#
#                        types  \
# 2                   ['T030']
# 3                   ['T082']
# 4                   ['T122']
# 5                   ['T169']
# 6                   ['T033']
# 7                   ['T122']
# 8                   ['T081']
# 9                   ['T081']
# 10                  ['T122']
# 11                  ['T122']
# 12  ['T109', 'T121', 'T127']
# 13  ['T109', 'T121', 'T127']
# 14  ['T109', 'T121', 'T127']
# 15  ['T109', 'T121', 'T127']
# 16                  ['T047']
# 17  ['T109', 'T121', 'T127']
# 18                  ['T059']
# 19  ['T109', 'T121', 'T127']
# 20                  ['T044']
# 21                  ['T044']
# 22  ['T109', 'T121', 'T127']
# 23                  ['T059']
# 24          ['T109', 'T127']
# 25          ['T121', 'T127']
# 26                  ['T121']
# 27                  ['T122']
# 28                  ['T081']
# 29                  ['T122']
# 30                  ['T122']
# 31                  ['T122']
# 33                  ['T079']
# 34                  ['T046']
# 35                  ['T060']
# 36                  ['T060']
# 37                  ['T047']
# 38                  ['T047']
# 39                  ['T046']
# 40                  ['T046']
# 42                  ['T058']
# 43                  ['T201']
# 44                  ['T170']
# 45                  ['T058']
# 46                  ['T079']
# 47                  ['T078']
# 48                  ['T074']
# 49                  ['T204']
# 50                  ['T080']
# 51                  ['T078']
# 52                  ['T023']
# 53                  ['T170']
#
#                                            definition
# 2   The oval-shaped oral cavity located at the ape...
# 3   Of, or relating to, or affecting, or for use i...
# 4   A substance intended for administration throug...
# 5   The introduction of a substance to the mouth o...
# 6   An intended site for a dose form that is for a...
# 7   Solid dosage forms, of varying weight, size, a...
# 8   A dosing unit equal to the amount of active in...
# 9                                                 NaN
# 10  A type of solid pharmaceutical dose form consi...
# 11         A tablet intended for oral administration.
# 12  A member of the vitamin B family that stimulat...
# 13  A group of water-soluble vitamins, some of whi...
# 14  Naturally occurring flavone or coumarin deriva...
# 15  A cobalt-containing coordination compound prod...
# 16  A condition due to deficiency in any member of...
# 17  A member of the vitamin B family that stimulat...
# 18  The determination of the amount of folic acid ...
# 19  The active metabolite of FOLIC ACID. Leucovori...
# 20  The chemical reactions and pathways resulting ...
# 21  Interacting selectively and non-covalently wit...
# 22  A six carbon compound related to glucose. It i...
# 23  The determination of the amount of Vitamin C p...
# 24  A nutrient that the body needs in small amount...
# 25                                                NaN
# 26                                                NaN
# 27  Solid dosage forms, of varying weight, size, a...
# 28  A dosing unit equal to the amount of active in...
# 29  A tablet designed to release active and/or ine...
# 30         A tablet intended for oral administration.
# 31  A tablet that will dissolve in a liquid solven...
# 33                        Occurring or done each day.
# 34  Altered reactivity to an antigen, which can re...
# 35  <p><b>Description:</b>Dianostic procedures ord...
# 36  An immune system procedure that observes for e...
# 37  Hypersensitivity in form of an adverse immune ...
# 38  state of altered reactivity in which the body ...
# 39  Immunologically mediated adverse reactions to ...
# 40  Altered reactivity to an antigen, which can re...
# 42  Actions performed to measure temperature, puls...
# 43  The signs of life that may be monitored or mea...
# 44  A subject domain utilized for the submission o...
# 45  The act of assessing an individual's current t...
# 46  The date on which a vital signs assessment is ...
# 47  A collection or single item of factual informa...
# 48  <p><b>Description:</b>This device can receive ...
# 49                                                NaN
# 50  Information regarding the subject is unknown o...
# 51  A string unique to a time duration of 24 hours...
# 52   A worm-like blind tube extension from the CECUM.
# 53  <p>Refers to a document serving as an appendix...

# %%
corpus.head(30)
# Out:
#     Unnamed: 0               name concept_id  \
# 0            0                  1       None
# 1            0                mg        None
# 2            0               oral   C0226896
# 3            1               oral   C0442027
# 4            2               oral   C1272919
# 5            3               oral   C1527415
# 6            4               oral   C4521986
# 7            0             tablet   C0039225
# 8            1             tablet   C1705223
# 9            2             tablet   C4319774
# 10           3             tablet   C4722631
# 11           4             tablet   C0993159
# 12           0  vitamin b complex   C0016410
# 13           1  vitamin b complex   C0042849
# 14           2  vitamin b complex   C0005492
# 15           3  vitamin b complex   C0042845
# 16           4  vitamin b complex   C0042850
# 17           0         folic acid   C0016410
# 18           1         folic acid   C0523631
# 19           2         folic acid   C0023413
# 20           3         folic acid   C1157038
# 21           4         folic acid   C1149539
# 22           0          vitamin c   C0003968
# 23           1          vitamin c   C0201898
# 24           2          vitamin c   C2349136
# 25           3          vitamin c   C3714687
# 26           4          vitamin c   C4522080
# 27           0               tab    C0039225
# 28           1               tab    C1705223
# 29           2               tab    C0991507
#
#                        canonical_name  \
# 0                           not_found
# 1                           not_found
# 2                         Oral cavity
# 3                                Oral
# 4                    Oral Dosage Form
# 5   Oral Route of Drug administration
# 6                Oral (intended site)
# 7                  Tablet Dosage Form
# 8                  Tablet Dosing Unit
# 9       Tablet (unit of presentation)
# 10        Tablet Dosage Form Category
# 11                        Oral Tablet
# 12                         folic acid
# 13                  vitamin B complex
# 14                      Bioflavonoids
# 15                        vitamin B12
# 16               Vitamin B Deficiency
# 17                         folic acid
# 18             Folic acid measurement
# 19                         leucovorin
# 20        Folate Biosynthesis Pathway
# 21                 folic acid binding
# 22                      ascorbic acid
# 23          Ascorbic acid measurement
# 24                 Vitamin C Vitamins
# 25               Vitamin C Drug Class
# 26                    Vitamin C [EPC]
# 27                 Tablet Dosage Form
# 28                 Tablet Dosing Unit
# 29       Extended Release Oral Tablet
#
#                                               aliases  \
# 0                                           not_found
# 1                                           not_found
# 2   ['Oral', 'Buccal Cavity', 'Buccal cavity', 'Or...
# 3   ['Oral', 'Orally', 'PO - Oral', 'oral', 'Oral ...
# 4   ['Oral', 'Oral Dosage Form', 'oral dosage form...
# 5   ['by mouth', 'PO - Per os', 'Oral Route of Adm...
# 6                    ['Oral', 'Oral (intended site)']
# 7   ['TAB', 'tab', 'TabletDrugForm', 'medicines ta...
# 8   ['Tablet Dosing Unit', '{Tablet}', 'Tablet', '...
# 9         ['Tablet', 'Tablet (unit of presentation)']
# 10          ['Tablet', 'Tablet Dosage Form Category']
# 11  ['oral tablets', 'Oral tablet', 'Conventional ...
# 12  ['Vitamin B c', 'Pteroyl-L-glutamic acid', 'Fo...
# 13  ['B Vitamins', 'Vitamin B and vitamin B deriva...
# 14  ['Product containing bioflavonoid', 'Bioflavon...
# 15  ['COBALAMIN', 'Cobalamin', 'vitamin-B12', 'CYA...
# 16  ['Deficiency of B-complex components', 'vitami...
# 17  ['Vitamin B c', 'Pteroyl-L-glutamic acid', 'Fo...
# 18  ['Folic acid measurement (procedure)', 'Folate...
# 19  ['L(-)-5-Formyl-5,6,7,8-tetrahydrofolic acid',...
# 20  ['folic acid synthesis', 'folate biosynthetic ...
# 21  ['folate binding', 'vitamin B9 binding', 'vita...
# 22  ['Vitamin-C', 'L-ascorbic acid', 'ácido ascórb...
# 23  ['Ascorbic Acid', 'Ascorbic acid measurement (...
# 24                                      ['Vitamin C']
# 25                                      ['VITAMIN C']
# 26  ['Vitamin C', 'Vitamin C-class Agent', 'Vitami...
# 27  ['TAB', 'tab', 'TabletDrugForm', 'medicines ta...
# 28  ['Tablet Dosing Unit', '{Tablet}', 'Tablet', '...
# 29  ['Extended-release oral tablet', 'Prolonged-re...
#
#                        types  \
# 0                       None
# 1                       None
# 2                   ['T030']
# 3                   ['T082']
# 4                   ['T122']
# 5                   ['T169']
# 6                   ['T033']
# 7                   ['T122']
# 8                   ['T081']
# 9                   ['T081']
# 10                  ['T122']
# 11                  ['T122']
# 12  ['T109', 'T121', 'T127']
# 13  ['T109', 'T121', 'T127']
# 14  ['T109', 'T121', 'T127']
# 15  ['T109', 'T121', 'T127']
# 16                  ['T047']
# 17  ['T109', 'T121', 'T127']
# 18                  ['T059']
# 19  ['T109', 'T121', 'T127']
# 20                  ['T044']
# 21                  ['T044']
# 22  ['T109', 'T121', 'T127']
# 23                  ['T059']
# 24          ['T109', 'T127']
# 25          ['T121', 'T127']
# 26                  ['T121']
# 27                  ['T122']
# 28                  ['T081']
# 29                  ['T122']
#
#                                            definition
# 0                                   not found in UMLS
# 1                                   not found in UMLS
# 2   The oval-shaped oral cavity located at the ape...
# 3   Of, or relating to, or affecting, or for use i...
# 4   A substance intended for administration throug...
# 5   The introduction of a substance to the mouth o...
# 6   An intended site for a dose form that is for a...
# 7   Solid dosage forms, of varying weight, size, a...
# 8   A dosing unit equal to the amount of active in...
# 9                                                 NaN
# 10  A type of solid pharmaceutical dose form consi...
# 11         A tablet intended for oral administration.
# 12  A member of the vitamin B family that stimulat...
# 13  A group of water-soluble vitamins, some of whi...
# 14  Naturally occurring flavone or coumarin deriva...
# 15  A cobalt-containing coordination compound prod...
# 16  A condition due to deficiency in any member of...
# 17  A member of the vitamin B family that stimulat...
# 18  The determination of the amount of folic acid ...
# 19  The active metabolite of FOLIC ACID. Leucovori...
# 20  The chemical reactions and pathways resulting ...
# 21  Interacting selectively and non-covalently wit...
# 22  A six carbon compound related to glucose. It i...
# 23  The determination of the amount of Vitamin C p...
# 24  A nutrient that the body needs in small amount...
# 25                                                NaN
# 26                                                NaN
# 27  Solid dosage forms, of varying weight, size, a...
# 28  A dosing unit equal to the amount of active in...
# 29  A tablet designed to release active and/or ine...

# %%
general = pd.DataFrame(corpus.loc[corpus['name'] == "vitamin"])
general.head(30)
# Out:
#       Unnamed: 0     name concept_id      canonical_name  \
# 7752           0  vitamin   C0042890            Vitamins
# 7753           1  vitamin   C2349136  Vitamin C Vitamins
# 7754           2  vitamin   C0035527          riboflavin
# 7755           3  vitamin   C0042839           vitamin A
# 7756           4  vitamin   C0087161   all-trans-retinol
#
#                                                 aliases  \
# 7752  ['Vitamin preparation, NOS', 'VITAMINS: MISCEL...
# 7753                                      ['Vitamin C']
# 7754  ['vitamin G', 'Riboflavin (substance)', 'Lacto...
# 7755  ['VITAMIN A', 'VITAMIN A PREPARATIONS', 'Retin...
# 7756  ['Vitamin A Alcohol', '3,7-dimethyl-9-(2,6, 6-...
#
#                          types  \
# 7752  ['T109', 'T121', 'T127']
# 7753          ['T109', 'T127']
# 7754  ['T109', 'T121', 'T127']
# 7755  ['T109', 'T121', 'T127']
# 7756  ['T109', 'T121', 'T127']
#
#                                              definition
# 7752  Organic substances that are required in small ...
# 7753  A nutrient that the body needs in small amount...
# 7754  Nutritional factor found in milk, eggs, malted...
# 7755  Retinol and derivatives of retinol that play a...
# 7756  A nutrient that the body needs in small amount...

# %%
corpus = corpus[corpus['definition'].notna()]

corpus.head(20)
# Out:
#     Unnamed: 0               name concept_id  \
# 0            0                  1       None
# 1            0                mg        None
# 2            0               oral   C0226896
# 3            1               oral   C0442027
# 4            2               oral   C1272919
# 5            3               oral   C1527415
# 6            4               oral   C4521986
# 7            0             tablet   C0039225
# 8            1             tablet   C1705223
# 10           3             tablet   C4722631
# 11           4             tablet   C0993159
# 12           0  vitamin b complex   C0016410
# 13           1  vitamin b complex   C0042849
# 14           2  vitamin b complex   C0005492
# 15           3  vitamin b complex   C0042845
# 16           4  vitamin b complex   C0042850
# 17           0         folic acid   C0016410
# 18           1         folic acid   C0523631
# 19           2         folic acid   C0023413
# 20           3         folic acid   C1157038
#
#                        canonical_name  \
# 0                           not_found
# 1                           not_found
# 2                         Oral cavity
# 3                                Oral
# 4                    Oral Dosage Form
# 5   Oral Route of Drug administration
# 6                Oral (intended site)
# 7                  Tablet Dosage Form
# 8                  Tablet Dosing Unit
# 10        Tablet Dosage Form Category
# 11                        Oral Tablet
# 12                         folic acid
# 13                  vitamin B complex
# 14                      Bioflavonoids
# 15                        vitamin B12
# 16               Vitamin B Deficiency
# 17                         folic acid
# 18             Folic acid measurement
# 19                         leucovorin
# 20        Folate Biosynthesis Pathway
#
#                                               aliases  \
# 0                                           not_found
# 1                                           not_found
# 2   ['Oral', 'Buccal Cavity', 'Buccal cavity', 'Or...
# 3   ['Oral', 'Orally', 'PO - Oral', 'oral', 'Oral ...
# 4   ['Oral', 'Oral Dosage Form', 'oral dosage form...
# 5   ['by mouth', 'PO - Per os', 'Oral Route of Adm...
# 6                    ['Oral', 'Oral (intended site)']
# 7   ['TAB', 'tab', 'TabletDrugForm', 'medicines ta...
# 8   ['Tablet Dosing Unit', '{Tablet}', 'Tablet', '...
# 10          ['Tablet', 'Tablet Dosage Form Category']
# 11  ['oral tablets', 'Oral tablet', 'Conventional ...
# 12  ['Vitamin B c', 'Pteroyl-L-glutamic acid', 'Fo...
# 13  ['B Vitamins', 'Vitamin B and vitamin B deriva...
# 14  ['Product containing bioflavonoid', 'Bioflavon...
# 15  ['COBALAMIN', 'Cobalamin', 'vitamin-B12', 'CYA...
# 16  ['Deficiency of B-complex components', 'vitami...
# 17  ['Vitamin B c', 'Pteroyl-L-glutamic acid', 'Fo...
# 18  ['Folic acid measurement (procedure)', 'Folate...
# 19  ['L(-)-5-Formyl-5,6,7,8-tetrahydrofolic acid',...
# 20  ['folic acid synthesis', 'folate biosynthetic ...
#
#                        types  \
# 0                       None
# 1                       None
# 2                   ['T030']
# 3                   ['T082']
# 4                   ['T122']
# 5                   ['T169']
# 6                   ['T033']
# 7                   ['T122']
# 8                   ['T081']
# 10                  ['T122']
# 11                  ['T122']
# 12  ['T109', 'T121', 'T127']
# 13  ['T109', 'T121', 'T127']
# 14  ['T109', 'T121', 'T127']
# 15  ['T109', 'T121', 'T127']
# 16                  ['T047']
# 17  ['T109', 'T121', 'T127']
# 18                  ['T059']
# 19  ['T109', 'T121', 'T127']
# 20                  ['T044']
#
#                                            definition
# 0                                   not found in UMLS
# 1                                   not found in UMLS
# 2   The oval-shaped oral cavity located at the ape...
# 3   Of, or relating to, or affecting, or for use i...
# 4   A substance intended for administration throug...
# 5   The introduction of a substance to the mouth o...
# 6   An intended site for a dose form that is for a...
# 7   Solid dosage forms, of varying weight, size, a...
# 8   A dosing unit equal to the amount of active in...
# 10  A type of solid pharmaceutical dose form consi...
# 11         A tablet intended for oral administration.
# 12  A member of the vitamin B family that stimulat...
# 13  A group of water-soluble vitamins, some of whi...
# 14  Naturally occurring flavone or coumarin deriva...
# 15  A cobalt-containing coordination compound prod...
# 16  A condition due to deficiency in any member of...
# 17  A member of the vitamin B family that stimulat...
# 18  The determination of the amount of folic acid ...
# 19  The active metabolite of FOLIC ACID. Leucovori...
# 20  The chemical reactions and pathways resulting ...

# %%
df_term_unique.head(20)
# Out:
#                    ann_text                                         definition
# 0               virt - vite  A mix of vitamins. It provides vitamin B-6, vi...
# 2                       mg         A tiny amount of something, usually a drug.
# 3                      oral                                    Taken by mouth.
# 4                    tablet                                            A pill.
# 5         vitamin b complex  A group of vitamins and nutrients.  The body n...
# 6                folic acid                                       A B vitamin.
# 7                 vitamin c  A nutrient needed by the body to form and main...
# 9                      tab                                             A pill.
# 10                       po                                          By mouth.
# 11                       qd                                         Every day.
# 12                allergies  Having a reaction to a drug or foreign substan...
# 13  no known drug allergies  The patient has not been shown to be allergic ...
# 14                      pm                        In the afternoon or evening.
# 15                   vitals  Measures that show how well the body is workin...
# 16              vital signs  Measures that show how well the body is workin...
# 17                    data                                        Information.
# 19                 appendix  A small, finger-like pouch at the beginning of...
# 21                treatment       Doing something to help a person get better.
# 23              ondansetron        A drug used to prevent nausea and vomiting.
# 27                      d5                       A mixture of sugar and water.

# %%
df_term_unique.reset_index(drop=True, inplace=True)

df_term_unique.head(20)
# Out:
#                    ann_text                                         definition
# 0               virt - vite  A mix of vitamins. It provides vitamin B-6, vi...
# 1                       mg         A tiny amount of something, usually a drug.
# 2                      oral                                    Taken by mouth.
# 3                    tablet                                            A pill.
# 4         vitamin b complex  A group of vitamins and nutrients.  The body n...
# 5                folic acid                                       A B vitamin.
# 6                 vitamin c  A nutrient needed by the body to form and main...
# 7                      tab                                             A pill.
# 8                        po                                          By mouth.
# 9                        qd                                         Every day.
# 10                allergies  Having a reaction to a drug or foreign substan...
# 11  no known drug allergies  The patient has not been shown to be allergic ...
# 12                      pm                        In the afternoon or evening.
# 13                   vitals  Measures that show how well the body is workin...
# 14              vital signs  Measures that show how well the body is workin...
# 15                    data                                        Information.
# 16                 appendix  A small, finger-like pouch at the beginning of...
# 17                treatment       Doing something to help a person get better.
# 18              ondansetron        A drug used to prevent nausea and vomiting.
# 19                      d5                       A mixture of sugar and water.

# %%
df_term_unique['sbert_def'] = ""

for i in range(len(df_term_unique)):
#     if i == 30:
#         break
#     print(i)
    term = df_term_unique['ann_text'].iloc[i]
#     print(term)
    general = corpus.loc[corpus['name'] == term]
#     print(len(general))
    if(len(general) != 0):
        corpus_term = general['definition'].tolist()
#         print(corpus_term[0])
        corpus_embeddings = embedder.encode(corpus_term, convert_to_tensor=True)
        query_term = df_term_unique['definition'].iloc[i]
        query_embedding = embedder.encode(query_term, convert_to_tensor=True)
        cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
        top_results = torch.topk(cos_scores, k=1)
        for score, idx in zip(top_results[0], top_results[1]):
            df_term_unique.at[i,'sbert_def'] = corpus_term[idx]

# %%
df_term_unique.head(30)
# Out:
#                    ann_text  \
# 0               virt - vite
# 1                       mg
# 2                      oral
# 3                    tablet
# 4         vitamin b complex
# 5                folic acid
# 6                 vitamin c
# 7                      tab
# 8                        po
# 9                        qd
# 10                allergies
# 11  no known drug allergies
# 12                      pm
# 13                   vitals
# 14              vital signs
# 15                    data
# 16                 appendix
# 17                treatment
# 18              ondansetron
# 19                      d5
# 20          sodium chloride
# 21                      ml
# 22                      hr
# 23                 iv fluid
# 24                     drip
# 25                 protonix
# 26              intravenous
# 27                      iv
# 28              medication
# 29                  iv push
#
#                                            definition  \
# 0   A mix of vitamins. It provides vitamin B-6, vi...
# 1         A tiny amount of something, usually a drug.
# 2                                     Taken by mouth.
# 3                                             A pill.
# 4   A group of vitamins and nutrients.  The body n...
# 5                                        A B vitamin.
# 6   A nutrient needed by the body to form and main...
# 7                                             A pill.
# 8                                           By mouth.
# 9                                          Every day.
# 10  Having a reaction to a drug or foreign substan...
# 11  The patient has not been shown to be allergic ...
# 12                       In the afternoon or evening.
# 13  Measures that show how well the body is workin...
# 14  Measures that show how well the body is workin...
# 15                                       Information.
# 16  A small, finger-like pouch at the beginning of...
# 17       Doing something to help a person get better.
# 18        A drug used to prevent nausea and vomiting.
# 19                      A mixture of sugar and water.
# 20  An element in the fluid (salt) surrounding cel...
# 21  A measurement of volume (5 milliliters is abou...
# 22  A measure of how fast or slow the heart is bea...
# 23  A mineral and salt water solution given throug...
# 24  A slow infusion of a medication via a tube int...
# 25  A drug used to treat heartburn and ulcers. It ...
# 26  When fluids and medicine are put directly into...
# 27  When fluids and medicine are put directly into...
# 28    A drug used to treat symptoms and cure illness.
# 29          Quickly injecting a medicine into a vein.
#
#                                             sbert_def
# 0
# 1                                   not found in UMLS
# 2   A substance intended for administration throug...
# 3          A tablet intended for oral administration.
# 4   A group of water-soluble vitamins, some of whi...
# 5   A member of the vitamin B family that stimulat...
# 6   A nutrient that the body needs in small amount...
# 7          A tablet intended for oral administration.
# 8                                   not found in UMLS
# 9                         Occurring or done each day.
# 10  state of altered reactivity in which the body ...
# 11  Immunologically mediated adverse reactions to ...
# 12                                  not found in UMLS
# 13
# 14  The act of assessing an individual's current t...
# 15  Information regarding the subject is unknown o...
# 16                    The distal end of the appendix.
# 17  Subject to a process with the aim of readying ...
# 18  The active ingredient in a drug used to treat ...
# 19
# 20  A crystalloid solution that contains 9.0g of S...
# 21                                  not found in UMLS
# 22                                  not found in UMLS
# 23  A sterile liquid preparation infused into a ve...
# 24  The administration of a drug within or into a ...
# 25
# 26  Into or within a vein. Intravenous usually ref...
# 27                                  not found in UMLS
# 28  A health/illness/pain management principle spe...
# 29                                  not found in UMLS

# %%
print(len(df_term_unique))
# Out:
# 42137

# %%
df_term_unique.to_csv("sentence_bert_top_definitions.csv")
